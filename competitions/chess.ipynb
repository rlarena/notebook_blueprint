# %% [markdown]
# # chess

# %%
from pettingzoo.classic import chess_v6

# %%
# install dependencies
# !git clone https://github.com/rlarena/notebook_blueprint.git > /dev/null 2>&1
# !pip install -r notebook_blueprint/requirements.txt
# Out:
# Requirement already satisfied: anyio==4.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: asttokens==2.4.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: async-lru==2.0.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: attrs==23.2.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: Babel==2.14.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 8)) (2.14.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 9)) (4.12.3)
# Requirement already satisfied: bleach==6.1.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: box2d-py==2.3.5 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 11)) (2.3.5)
# Requirement already satisfied: certifi==2024.2.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 12)) (2024.2.2)
# Requirement already satisfied: cffi==1.16.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 14)) (3.3.2)
# Requirement already satisfied: cloudpickle==3.0.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: comm==0.2.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: contourpy==1.2.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: cycler==0.12.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 19)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 20)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 21)) (0.7.1)
# Requirement already satisfied: exceptiongroup==1.2.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 22)) (1.2.0)
# Requirement already satisfied: executing==2.0.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 23)) (2.0.1)
# Requirement already satisfied: Farama-Notifications==0.0.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 24)) (0.0.4)
# Requirement already satisfied: fastjsonschema==2.19.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 25)) (2.19.1)
# Requirement already satisfied: filelock==3.13.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 26)) (3.13.4)
# Requirement already satisfied: fonttools==4.51.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 27)) (4.51.0)
# Requirement already satisfied: fqdn==1.5.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 28)) (1.5.1)
# Requirement already satisfied: fsspec==2024.3.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 29)) (2024.3.1)
# Requirement already satisfied: gymnasium==0.29.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 30)) (0.29.1)
# Requirement already satisfied: h11==0.14.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 31)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 32)) (1.0.5)
# Requirement already satisfied: httpx==0.27.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 33)) (0.27.0)
# Requirement already satisfied: idna==3.7 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 34)) (3.7)
# Requirement already satisfied: ipykernel==6.29.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 35)) (6.29.4)
# Requirement already satisfied: ipython==8.23.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 36)) (8.23.0)
# Requirement already satisfied: ipywidgets==8.1.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 37)) (8.1.2)
# Requirement already satisfied: isoduration==20.11.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 38)) (20.11.0)
# Requirement already satisfied: jedi==0.19.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 39)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 40)) (3.1.3)
# Requirement already satisfied: json5==0.9.25 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 41)) (0.9.25)
# Requirement already satisfied: jsonpointer==2.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 42)) (2.4)
# Requirement already satisfied: jsonschema==4.21.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 43)) (4.21.1)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 44)) (2023.12.1)
# Requirement already satisfied: jupyter==1.0.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 45)) (1.0.0)
# Requirement already satisfied: jupyter-console==6.6.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 46)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.10.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 47)) (0.10.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 48)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 49)) (8.6.1)
# Requirement already satisfied: jupyter_core==5.7.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 50)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.14.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 51)) (2.14.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 52)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.1.6 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 53)) (4.1.6)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 54)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.26.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 55)) (2.26.0)
# Requirement already satisfied: jupyterlab_widgets==3.0.10 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 56)) (3.0.10)
# Requirement already satisfied: kiwisolver==1.4.5 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 57)) (1.4.5)
# Requirement already satisfied: MarkupSafe==2.1.5 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 58)) (2.1.5)
# Requirement already satisfied: matplotlib==3.8.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 59)) (3.8.4)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 60)) (0.1.7)
# Requirement already satisfied: mistune==3.0.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 61)) (3.0.2)
# Requirement already satisfied: mpmath==1.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 62)) (1.3.0)
# Requirement already satisfied: nbclient==0.10.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 63)) (0.10.0)
# Requirement already satisfied: nbconvert==7.16.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 64)) (7.16.3)
# Requirement already satisfied: nbformat==5.10.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 65)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 66)) (1.6.0)
# Requirement already satisfied: networkx==3.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 67)) (3.3)
# Requirement already satisfied: notebook==7.1.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 68)) (7.1.3)
# Requirement already satisfied: notebook_shim==0.2.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 69)) (0.2.4)
# Requirement already satisfied: numpy==1.26.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 70)) (1.26.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 71)) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 72)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 73)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 74)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 75)) (8.9.2.26)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 76)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 77)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 78)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 79)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 80)) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 81)) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 82)) (12.1.105)
# Requirement already satisfied: overrides==7.7.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 83)) (7.7.0)
# Requirement already satisfied: packaging==24.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 84)) (24.0)
# Requirement already satisfied: pandas==2.2.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 85)) (2.2.2)
# Requirement already satisfied: pandocfilters==1.5.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 86)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 87)) (0.8.4)
# Requirement already satisfied: pettingzoo==1.24.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 88)) (1.24.3)
# Requirement already satisfied: pexpect==4.9.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 89)) (4.9.0)
# Requirement already satisfied: pillow==10.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 90)) (10.3.0)
# Requirement already satisfied: platformdirs==4.2.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 91)) (4.2.0)
# Requirement already satisfied: prometheus_client==0.20.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 92)) (0.20.0)
# Requirement already satisfied: prompt-toolkit==3.0.43 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 93)) (3.0.43)
# Requirement already satisfied: psutil==5.9.8 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 94)) (5.9.8)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 95)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 96)) (0.2.2)
# Requirement already satisfied: pycparser==2.22 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 97)) (2.22)
# Requirement already satisfied: pygame==2.5.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 98)) (2.5.2)
# Requirement already satisfied: Pygments==2.17.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 99)) (2.17.2)
# Requirement already satisfied: pyparsing==3.1.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 100)) (3.1.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 101)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.7 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 102)) (2.0.7)
# Requirement already satisfied: pytz==2024.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 103)) (2024.1)
# Requirement already satisfied: PyYAML==6.0.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 104)) (6.0.1)
# Requirement already satisfied: pyzmq==26.0.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 105)) (26.0.0)
# Requirement already satisfied: qtconsole==5.5.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 106)) (5.5.1)
# Requirement already satisfied: QtPy==2.4.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 107)) (2.4.1)
# Requirement already satisfied: referencing==0.34.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 108)) (0.34.0)
# Requirement already satisfied: requests==2.31.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 109)) (2.31.0)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 110)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 111)) (0.1.1)
# Requirement already satisfied: rpds-py==0.18.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 112)) (0.18.0)
# Requirement already satisfied: Send2Trash==1.8.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 113)) (1.8.3)
# Requirement already satisfied: six==1.16.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 114)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 115)) (1.3.1)
# Requirement already satisfied: soupsieve==2.5 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 116)) (2.5)
# Requirement already satisfied: stable_baselines3==2.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 117)) (2.3.0)
# Requirement already satisfied: stack-data==0.6.3 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 118)) (0.6.3)
# Requirement already satisfied: swig==4.2.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 119)) (4.2.1)
# Requirement already satisfied: sympy==1.12 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 120)) (1.12)
# Requirement already satisfied: terminado==0.18.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 121)) (0.18.1)
# Requirement already satisfied: tinycss2==1.2.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 122)) (1.2.1)
# Requirement already satisfied: tomli==2.0.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 123)) (2.0.1)
# Requirement already satisfied: torch==2.2.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 124)) (2.2.2)
# Requirement already satisfied: tornado==6.4 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 125)) (6.4)
# Requirement already satisfied: traitlets==5.14.2 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 126)) (5.14.2)
# Requirement already satisfied: triton==2.2.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 127)) (2.2.0)
# Requirement already satisfied: types-python-dateutil==2.9.0.20240316 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 128)) (2.9.0.20240316)
# Requirement already satisfied: typing_extensions==4.11.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 129)) (4.11.0)
# Requirement already satisfied: tzdata==2024.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 130)) (2024.1)
# Requirement already satisfied: uri-template==1.3.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 131)) (1.3.0)
# Requirement already satisfied: urllib3==2.2.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 132)) (2.2.1)
# Requirement already satisfied: wcwidth==0.2.13 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 133)) (0.2.13)
# Requirement already satisfied: webcolors==1.13 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 134)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 135)) (0.5.1)
# Requirement already satisfied: websocket-client==1.7.0 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 136)) (1.7.0)
# Requirement already satisfied: widgetsnbextension==4.0.10 in /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages (from -r notebook_blueprint/requirements.txt (line 137)) (4.0.10)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
env = chess_v6.env()
env.reset(seed=42)
cum_reward = {agent:0 for agent in env.agents}

# interact with env
for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()
    cum_reward[agent] += reward
    if termination or truncation:
        action = None
    else:
        mask = observation["action_mask"]
        # this is where you would insert your policy
        action = env.action_space(agent).sample(mask)

    env.step(action)
env.close()
print(cum_reward)
# Out:
# {'player_0': 0, 'player_1': 0}

# %% [markdown]
# ## Train agent

# %%
model_path = "my_model.zip"

# %%
import glob
import os
import time

from sb3_contrib import MaskablePPO
from sb3_contrib.common.maskable.policies import MaskableActorCriticPolicy
from sb3_contrib.common.wrappers import ActionMasker

import pettingzoo.utils
from pettingzoo.classic import chess_v6


class SB3ActionMaskWrapper(pettingzoo.utils.BaseWrapper):
    """Wrapper to allow PettingZoo environments to be used with SB3 illegal action masking."""

    def reset(self, seed=None, options=None):
        """Gymnasium-like reset function which assigns obs/action spaces to be the same for each agent.

        This is required as SB3 is designed for single-agent RL and doesn't expect obs/action spaces to be functions
        """
        super().reset(seed, options)

        # Strip the action mask out from the observation space
        self.observation_space = super().observation_space(self.possible_agents[0])[
            "observation"
        ]
        self.action_space = super().action_space(self.possible_agents[0])

        # Return initial observation, info (PettingZoo AEC envs do not by default)
        return self.observe(self.agent_selection), {}

    def step(self, action):
        """Gymnasium-like step function, returning observation, reward, termination, truncation, info."""
        super().step(action)
        return super().last()

    def observe(self, agent):
        """Return only raw observation, removing action mask."""
        return super().observe(agent)["observation"]

    def action_mask(self):
        """Separate function used in order to access the action mask."""
        return super().observe(self.agent_selection)["action_mask"]


def mask_fn(env):
    return env.action_mask()


def train_action_mask(env_fn, steps=10_000, seed=0, **env_kwargs):
    """Train a single model to play as each agent in a zero-sum game environment using invalid action masking."""
    env = env_fn.env(**env_kwargs)

    print(f"Starting training on {str(env.metadata['name'])}.")

    # Custom wrapper to convert PettingZoo envs to work with SB3 action masking
    env = SB3ActionMaskWrapper(env)

    env.reset(seed=seed)  # Must call reset() in order to re-define the spaces

    env = ActionMasker(env, mask_fn)  # Wrap to enable masking (SB3 function)
    # MaskablePPO behaves the same as SB3's PPO unless the env is wrapped
    # with ActionMasker. If the wrapper is detected, the masks are automatically
    # retrieved and used when learning. Note that MaskablePPO does not accept
    # a new action_mask_fn kwarg, as it did in an earlier draft.
    model = MaskablePPO(MaskableActorCriticPolicy, env, verbose=1)
    model.set_random_seed(seed)
    model.learn(total_timesteps=steps)

    model.save(model_path)

    print("Model has been saved.")

    print(f"Finished training on {str(env.unwrapped.metadata['name'])}.\n")

    env.close()


def eval_action_mask(env_fn, num_games=100, render_mode=None, **env_kwargs):
    # Evaluate a trained agent vs a random agent
    env = env_fn.env(render_mode=render_mode, **env_kwargs)

    print(
        f"Starting evaluation vs a random agent. Trained agent will play as {env.possible_agents[1]}."
    )

    try:
        latest_policy = max(
            glob.glob(f"{env.metadata['name']}*.zip"), key=os.path.getctime
        )
    except ValueError:
        print("Policy not found.")
        exit(0)

    model = MaskablePPO.load(latest_policy)

    scores = {agent: 0 for agent in env.possible_agents}
    total_rewards = {agent: 0 for agent in env.possible_agents}
    round_rewards = []

    for i in range(num_games):
        env.reset(seed=i)
        env.action_space(env.possible_agents[0]).seed(i)

        for agent in env.agent_iter():
            obs, reward, termination, truncation, info = env.last()

            # Separate observation and action mask
            observation, action_mask = obs.values()

            if termination or truncation:
                # If there is a winner, keep track, otherwise don't change the scores (tie)
                if (
                    env.rewards[env.possible_agents[0]]
                    != env.rewards[env.possible_agents[1]]
                ):
                    winner = max(env.rewards, key=env.rewards.get)
                    scores[winner] += env.rewards[
                        winner
                    ]  # only tracks the largest reward (winner of game)
                # Also track negative and positive rewards (penalizes illegal moves)
                for a in env.possible_agents:
                    total_rewards[a] += env.rewards[a]
                # List of rewards by round, for reference
                round_rewards.append(env.rewards)
                break
            else:
                if agent == env.possible_agents[0]:
                    act = env.action_space(agent).sample(action_mask)
                else:
                    # Note: PettingZoo expects integer actions # TODO: change chess to cast actions to type int?
                    act = int(
                        model.predict(
                            observation, action_masks=action_mask, deterministic=True
                        )[0]
                    )
            env.step(act)
    env.close()

    # Avoid dividing by zero
    if sum(scores.values()) == 0:
        winrate = 0
    else:
        winrate = scores[env.possible_agents[1]] / sum(scores.values())
    print("Rewards by round: ", round_rewards)
    print("Total rewards (incl. negative rewards): ", total_rewards)
    print("Winrate: ", winrate)
    print("Final scores: ", scores)
    return round_rewards, total_rewards, winrate, scores

# %%
env_fn = chess_v6
env_kwargs = {}
train_action_mask(env_fn, steps=20_480, seed=0, **env_kwargs)
# Out:
# Starting training on chess_v6.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/raphael/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.action_masks to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_masks` for environment variables or `env.get_wrapper_attr('action_masks')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 270      |
# |    ep_rew_mean     | -0.286   |
# | time/              |          |
# |    fps             | 291      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | -0.154      |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 2           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.034519576 |
# |    clip_fraction        | 0.474       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | -0.622      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.142      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.103      |
# |    value_loss           | 0.00685     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 315        |
# |    ep_rew_mean          | -0.158     |
# | time/                   |            |
# |    fps                  | 178        |
# |    iterations           | 3          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.04102739 |
# |    clip_fraction        | 0.538      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.0558     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.133     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.114     |
# |    value_loss           | 0.000743   |
# ----------------------------------------

# %%
# Evaluate 100 games against a random agent
res = eval_action_mask(env_fn, num_games=100, render_mode=None, **env_kwargs)
# Out:
# Starting evaluation vs a random agent. Trained agent will play as player_1.
# Rewards by round:  [{'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': 1, 'player_1': -1}, {'player_0': -1, 'player_1': 1}, {'player_0': 1, 'player_1': -1}]
# Total rewards (incl. negative rewards):  {'player_0': 46, 'player_1': -46}
# Winrate:  0.27
# Final scores:  {'player_0': 73, 'player_1': 27}

# %% [markdown]
# ## Publish agent

# %%
class Agent:
    def __init__(self, env):
        self.env = env
        from stable_baselines3 import DQN
        self.model =  DQN.load(model_path)

    def choose_action(self, observation, action_mask=None):
        action, _states = self.model.predict(observation, deterministic=True)
        return action

# %%
my_stringify_agent = f"""
class Agent:
    def __init__(self, env):
        self.env = env
        from stable_baselines3 import DQN
        self.model =  DQN.load("{model_path}")

    def choose_action(self, observation, action_mask=None):
        action, _states = self.model.predict(observation, deterministic=True)
        return action
"""

# %%
# go to https://rlarena.com/my-profile to get or generate your key pair
key_id=""
key_pass=""
#
agent_attach_name= "my_super_agent"

# %%
import requests
import io

def attach_agent(key_id, key_pass, agent_attach_name, model_path):
    # Endpoint URL
    url = 'https://rlarena.com/api/direct_attache_agents_notebook/competition/4'

    # Your credentials and agent details
    data = {
        'key_id': key_id,
        'key_pass': key_pass,
        'agent_attach_name': agent_attach_name,
    }

    # Files to upload: agent.py and the model
    files = {
        'model': (model_path, open(model_path, 'rb')),
        'agent_code': ('agent.py', io.StringIO(my_stringify_agent)),
    }

    # Make the POST request
    try:
        response = requests.post(url, data=data, files=files)
        # Ensure files are closed properly
        files['model'][1].close()
        files['agent_code'][1].close()
        return response.json()  # Return the JSON response
    except Exception as e:
        print(f"Failed to attach agent due to: {str(e)}")
        return None


response = attach_agent(key_id, key_pass, agent_attach_name, model_path)
print(response)
# Out:
# {'attache_agent_id': 6, 'message': 'Uploaded successfully: my_model.zip, agent.py'}
