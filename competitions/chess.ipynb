# %% [markdown]
# # chess

# %%
# install dependencies
# !pip install swig==4.2.1 2>&1
# !pip install gymnasium==0.29.1 2>&1
# !pip install pettingzoo[classic]==1.24.3 2>&1
# !pip install box2d-py==2.3.5 2>&1
# !pip install stable_baselines3==2.3.0 2>&1
# !pip install sb3_contrib==2.3.0 2>&1

# %%
from pettingzoo.classic import chess_v6

# %%
env = chess_v6.env()
env.reset(seed=42)
cum_reward = {agent:0 for agent in env.agents}

# interact with env
for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()
    cum_reward[agent] += reward
    if termination or truncation:
        action = None
    else:
        mask = observation["action_mask"]
        # this is where you would insert your policy
        action = env.action_space(agent).sample(mask)

    env.step(action)
env.close()
print(cum_reward)

# %%
class Agent:
    def __init__(self, env):
        self.env = env

    def choose_action(self, observation, action_mask=None):
        if self.env.action_space.__class__.__name__ == "method":  # Multiplayer env
            action = self.env.action_space(self.env.agents[0]).sample(action_mask)
        else:  # Classic gymnasium
            action = self.env.action_space.sample()
        return action

# %%
for _ in range(100):
    env = chess_v6.env()
    env.reset()#seed=423)
    cum_reward = {agent:0 for agent in env.agents}
    last_done = {agent: False for agent in env.agents}
    observation, reward, termination, truncation, info = env.last()
    agents = env.agents
    
    ft_agent = Agent(env)
    
    # interact with env
    while not all(last_done.values()):
        for agent in agents:
            if any(last_done.values()):
                action = None
            else:
                mask = observation["action_mask"]
                # this is where you would insert your policy
                action = ft_agent.choose_action(observation['observation'], observation['action_mask'])#env.action_space(agent).sample(mask)
            
            env.step(action)
            observation, reward, termination, truncation, info = env.last()
            print(cum_reward)
            cum_reward[agent] += reward
            print(cum_reward)
            last_done[agent] = termination or truncation
            print(agent, action, reward, last_done)
            print(env.agents)
    print(cum_reward)
    print(env.agents)
    env.close()
# Out:
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 645 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2997 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4165 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 669 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4238 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 85 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 85 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2413 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1377 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3070 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4092 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1775 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2618 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 645 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3005 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2343 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3561 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2993 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2337 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3589 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1178 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 596 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4164 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4165 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2421 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2471 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1245 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1372 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2343 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3146 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2922 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4092 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2411 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2922 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 661 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 645 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3000 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2486 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1766 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 805 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1916 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 734 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3141 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4236 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4311 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4173 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2632 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3581 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1829 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4310 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1175 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1377 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 380 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2419 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 606 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2616 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2935 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1759 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1840 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2414 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2337 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3344 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1318 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2921 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3155 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1402 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 734 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2717 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4092 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3803 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1684 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2340 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1178 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1253 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1756 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2907 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3565 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3347 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1839 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3563 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2559 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3127 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3026 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3852 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4292 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2613 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4194 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1389 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1242 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 761 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3650 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1884 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 660 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2416 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 153 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1447 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 77 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4237 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 614 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4439 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 826 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3071 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 149 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3580 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2953 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1882 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2782 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4210 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1460 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 296 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 826 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 792 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2703 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 823 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2997 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 223 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3072 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1044 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2798 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2791 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 38 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1041 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 103 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3727 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2945 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3999 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2423 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3506 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3586 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 804 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 606 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 233 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2361 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 76 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2194 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2999 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2285 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3580 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2418 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3652 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1391 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1902 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 604 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3563 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 841 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 169 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3729 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2133 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1487 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1174 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 612 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4340 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 882 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1780 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3139 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2071 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1263 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1764 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1466 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1912 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 151 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3508 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 672 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3578 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3125 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2995 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2691 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3070 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3930 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2485 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3002 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3142 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1971 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3102 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1316 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2413 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2066 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3445 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3837 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4626 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4655 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4324 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 322 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2487 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2637 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3800 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1474 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2997 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2642 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3067 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 834 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 296 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1826 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2482 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3802 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1832 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3439 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2482 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1250 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1827 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2483 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1319 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1899 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3873 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 79 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4010 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4429 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1825 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 671 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1175 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2133 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1832 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 185 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4031 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1318 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2057 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 338 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3074 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3463 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1775 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1839 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3728 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3010 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2489 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1250 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4236 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 153 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3733 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 87 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2706 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 826 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3227 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1244 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3140 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1177 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4526 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 22 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2558 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1387 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3874 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 733 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4380 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 660 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3730 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1788 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2485 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2131 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4382 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3304 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2409 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 585 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3871 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3080 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3365 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4259 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4031 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1759 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1904 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2049 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 586 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2410 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2486 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2573 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2559 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1826 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2645 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1022 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 888 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1248 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1033 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1898 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 78 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 394 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 898 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1241 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2639 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2419 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 591 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1389 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2491 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 588 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1315 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 657 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 768 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 891 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3651 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2197 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3077 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2868 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2945 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4404 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1246 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1762 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 585 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 730 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 12 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 174 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 586 0 {'player_0': False, 'player_1': True}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 None 0 {'player_0': True, 'player_1': True}
# ['player_1']
# {'player_0': 0, 'player_1': 0}
# ['player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4173 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3589 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4100 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 77 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2413 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 669 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3005 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3725 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4235 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3219 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1837 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1829 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1759 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3565 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 643 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1902 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3563 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2421 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 6 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2930 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 669 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1170 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3125 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4293 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1175 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2350 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2688 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 150 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 805 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1916 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 596 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1783 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1245 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# ...
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1554 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3728 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3071 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 80 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3577 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 732 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2927 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4244 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3577 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3230 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1905 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1679 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2560 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1059 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2927 0 {'player_0': True, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 None 0 {'player_0': True, 'player_1': True}
# ['player_0']
# {'player_0': 0, 'player_1': 0}
# ['player_0']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2413 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 669 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3589 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3563 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3005 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3123 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1253 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1178 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2340 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2997 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1837 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1753 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 669 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2413 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1762 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2030 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2412 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1593 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1389 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 153 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 736 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 826 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2340 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4173 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3565 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3070 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 647 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2922 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1886 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3581 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2416 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1174 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3072 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4311 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3650 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4092 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 77 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4164 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2927 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2028 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1320 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4108 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2616 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2342 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2993 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3654 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3348 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 4318 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 2343 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 2926 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 3577 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3506 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 1916 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 1758 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 376 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 85 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 153 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_1 3725 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# {'player_0': 0, 'player_1': 0}
# {'player_0': 0, 'player_1': 0}
# player_0 4292 0 {'player_0': False, 'player_1': False}
# ['player_0', 'player_1']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      18     # this is where you would insert your policy
#      19     action = ft_agent.choose_action(observation['observation'], observation['action_mask'])#env.action_space(agent).sample(mask)
# ---> 21 env.step(action)
#      22 observation, reward, termination, truncation, info = env.last()
#      23 print(cum_reward)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/utils/wrappers/order_enforcing.py:96, in OrderEnforcingWrapper.step(self, action)
#      94 else:
#      95     self._has_updated = True
# ---> 96     super().step(action)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/utils/wrappers/assert_out_of_bounds.py:26, in AssertOutOfBoundsWrapper.step(self, action)
#      16 def step(self, action: ActionType) -> None:
#      17     assert (
#      18         action is None
#      19         and (
#    (...)
#      24         action
#      25     ), "action is not in action space"
# ---> 26     super().step(action)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/utils/wrappers/terminate_illegal.py:81, in TerminateIllegalWrapper.step(self, action)
#      79     self._terminated = True
#      80 else:
# ---> 81     super().step(action)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/classic/chess/chess.py:278, in raw_env.step(self, action)
#     275 assert chosen_move in self.board.legal_moves
#     276 self.board.push(chosen_move)
# --> 278 next_legal_moves = chess_utils.legal_moves(self.board)
#     280 is_stale_or_checkmate = not any(next_legal_moves)
#     282 # claim draw is set to be true to align with normal tournament rules
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/pettingzoo/classic/chess/chess_utils.py:188, in legal_moves(orig_board)
#     185     board = orig_board
#     187 legal_moves = []
# --> 188 for move in board.legal_moves:
#     189     uci_move = move.uci()
#     190     if uci_move in moves_to_actions:
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/chess/__init__.py:3569, in Board.generate_legal_moves(self, from_mask, to_mask)
#    3567     else:
#    3568         for move in self.generate_pseudo_legal_moves(from_mask, to_mask):
# -> 3569             if self._is_safe(king, blockers, move):
#    3570                 yield move
#    3571 else:
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/chess/__init__.py:3521, in Board._is_safe(self, king, blockers, move)
#    3519         return True
#    3520     else:
# -> 3521         return not self.is_attacked_by(not self.turn, move.to_square)
#    3522 elif self.is_en_passant(move):
#    3523     return bool(self.pin_mask(self.turn, move.from_square) & BB_SQUARES[move.to_square] and
#    3524                 not self._ep_skewered(king, move.from_square))
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/chess/__init__.py:809, in BaseBoard.is_attacked_by(self, color, square)
#     802 def is_attacked_by(self, color: Color, square: Square) -> bool:
#     803     """
#     804     Checks if the given side attacks the given square.
#     805
#     806     Pinned pieces still count as attackers. Pawns that can be captured
#     807     en passant are **not** considered attacked.
#     808     """
# --> 809     return bool(self.attackers_mask(color, square))
#
# File ~/.cache/pypoetry/virtualenvs/notebook-blueprint-S0X6msc3-py3.10/lib/python3.10/site-packages/chess/__init__.py:799, in BaseBoard.attackers_mask(self, color, square)
#     789     attackers = (
#     790         (BB_KING_ATTACKS[square] & self.kings) |
#     791         (BB_KNIGHT_ATTACKS[square] & self.knights) |
#    (...)
#     794         (BB_DIAG_ATTACKS[square][diag_pieces] & queens_and_bishops) |
#     795         (BB_PAWN_ATTACKS[not color][square] & self.pawns))
#     797     return attackers & self.occupied_co[color]
# --> 799 def attackers_mask(self, color: Color, square: Square) -> Bitboard:
#     800     return self._attackers_mask(color, square, self.occupied)
#     802 def is_attacked_by(self, color: Color, square: Square) -> bool:
#
# KeyboardInterrupt:

# %%
env = chess_v6.env()
env.reset(seed=42)
env.last()[0]['action_mask']

# %% [markdown]
# ## Train agent

# %%
model_path = "my_model.zip"

# %%
import glob
import os
import time

from sb3_contrib import MaskablePPO
from sb3_contrib.common.maskable.policies import MaskableActorCriticPolicy
from sb3_contrib.common.wrappers import ActionMasker

import pettingzoo.utils
from pettingzoo.classic import chess_v6


class SB3ActionMaskWrapper(pettingzoo.utils.BaseWrapper):
    """Wrapper to allow PettingZoo environments to be used with SB3 illegal action masking."""

    def reset(self, seed=None, options=None):
        """Gymnasium-like reset function which assigns obs/action spaces to be the same for each agent.

        This is required as SB3 is designed for single-agent RL and doesn't expect obs/action spaces to be functions
        """
        super().reset(seed, options)

        # Strip the action mask out from the observation space
        self.observation_space = super().observation_space(self.possible_agents[0])[
            "observation"
        ]
        self.action_space = super().action_space(self.possible_agents[0])

        # Return initial observation, info (PettingZoo AEC envs do not by default)
        return self.observe(self.agent_selection), {}

    def step(self, action):
        """Gymnasium-like step function, returning observation, reward, termination, truncation, info."""
        super().step(action)
        return super().last()

    def observe(self, agent):
        """Return only raw observation, removing action mask."""
        return super().observe(agent)["observation"]

    def action_mask(self):
        """Separate function used in order to access the action mask."""
        return super().observe(self.agent_selection)["action_mask"]


def mask_fn(env):
    return env.action_mask()


def train_action_mask(env_fn, steps=10_000, seed=0, **env_kwargs):
    """Train a single model to play as each agent in a zero-sum game environment using invalid action masking."""
    env = env_fn.env(**env_kwargs)

    print(f"Starting training on {str(env.metadata['name'])}.")

    # Custom wrapper to convert PettingZoo envs to work with SB3 action masking
    env = SB3ActionMaskWrapper(env)

    env.reset(seed=seed)  # Must call reset() in order to re-define the spaces

    env = ActionMasker(env, mask_fn)  # Wrap to enable masking (SB3 function)
    # MaskablePPO behaves the same as SB3's PPO unless the env is wrapped
    # with ActionMasker. If the wrapper is detected, the masks are automatically
    # retrieved and used when learning. Note that MaskablePPO does not accept
    # a new action_mask_fn kwarg, as it did in an earlier draft.
    model = MaskablePPO(MaskableActorCriticPolicy, env, verbose=1)
    model.set_random_seed(seed)
    model.learn(total_timesteps=steps)

    model.save(model_path)

    print("Model has been saved.")

    print(f"Finished training on {str(env.unwrapped.metadata['name'])}.\n")

    env.close()


def eval_action_mask(env_fn, num_games=100, render_mode=None, **env_kwargs):
    # Evaluate a trained agent vs a random agent
    env = env_fn.env(render_mode=render_mode, **env_kwargs)

    print(
        f"Starting evaluation vs a random agent. Trained agent will play as {env.possible_agents[1]}."
    )


    model = MaskablePPO.load(model_path)

    scores = {agent: 0 for agent in env.possible_agents}
    total_rewards = {agent: 0 for agent in env.possible_agents}
    round_rewards = []

    for i in range(num_games):
        env.reset(seed=i)
        env.action_space(env.possible_agents[0]).seed(i)

        for agent in env.agent_iter():
            obs, reward, termination, truncation, info = env.last()

            # Separate observation and action mask
            observation, action_mask = obs.values()

            if termination or truncation:
                # If there is a winner, keep track, otherwise don't change the scores (tie)
                if (
                    env.rewards[env.possible_agents[0]]
                    != env.rewards[env.possible_agents[1]]
                ):
                    winner = max(env.rewards, key=env.rewards.get)
                    scores[winner] += env.rewards[
                        winner
                    ]  # only tracks the largest reward (winner of game)
                # Also track negative and positive rewards (penalizes illegal moves)
                for a in env.possible_agents:
                    total_rewards[a] += env.rewards[a]
                # List of rewards by round, for reference
                round_rewards.append(env.rewards)
                break
            else:
                if agent == env.possible_agents[0]:
                    act = env.action_space(agent).sample(action_mask)
                else:
                    # Note: PettingZoo expects integer actions # TODO: change chess to cast actions to type int?
                    act = int(
                        model.predict(
                            observation, action_masks=action_mask, deterministic=True
                        )[0]
                    )
            env.step(act)
    env.close()

    # Avoid dividing by zero
    if sum(scores.values()) == 0:
        winrate = 0
    else:
        winrate = scores[env.possible_agents[1]] / sum(scores.values())
    print("Rewards by round: ", round_rewards)
    print("Total rewards (incl. negative rewards): ", total_rewards)
    print("Winrate: ", winrate)
    print("Final scores: ", scores)
    return round_rewards, total_rewards, winrate, scores

# %%
env_fn = chess_v6
env_kwargs = {}
train_action_mask(env_fn, steps=20_480, seed=0, **env_kwargs)

# %%
# Evaluate 100 games against a random agent
res = eval_action_mask(env_fn, num_games=100, render_mode=None, **env_kwargs)

# %% [markdown]
# ## Publish agent

# %%
class Agent:
    def __init__(self, env):
        self.env = env
        from sb3_contrib import MaskablePPO
        self.model =  MaskablePPO.load(model_path)

    def choose_action(self, observation, action_mask=None):
        action, _states = self.model.predict(observation, deterministic=True)
        return action

# %%
my_stringify_agent = f"""
class Agent:
    def __init__(self, env):
        self.env = env
        from sb3_contrib import MaskablePPO
        self.model =  MaskablePPO.load("{model_path}")

    def choose_action(self, observation, action_mask=None):
        action, _states = self.model.predict(observation, deterministic=True)
        return action
"""

# %%
# go to https://rlarena.com/my-profile to get or generate your key pair
key_id=""
key_pass=""
#
agent_attach_name= "my_super_agent"

# %%
import requests
import io

def attach_agent(key_id, key_pass, agent_attach_name, model_path):
    # Endpoint URL
    url = 'https://rlarena.com/api/direct_attache_agents_notebook/competition/4'

    # Your credentials and agent details
    data = {
        'key_id': key_id,
        'key_pass': key_pass,
        'agent_attach_name': agent_attach_name,
    }

    # Files to upload: agent.py and the model
    files = {
        'model': (model_path, open(model_path, 'rb')),
        'agent_code': ('agent.py', io.StringIO(my_stringify_agent)),
    }

    # Make the POST request
    try:
        response = requests.post(url, data=data, files=files)
        # Ensure files are closed properly
        files['model'][1].close()
        files['agent_code'][1].close()
        return response.json()  # Return the JSON response
    except Exception as e:
        print(f"Failed to attach agent due to: {str(e)}")
        return None


response = attach_agent(key_id, key_pass, agent_attach_name, model_path)
print(response)
